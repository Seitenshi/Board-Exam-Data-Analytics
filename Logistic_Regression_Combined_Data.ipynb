# %% [markdown]
# <a href="https://colab.research.google.com/github/Seitenshi/Board-Exam-Data-Analytics/blob/main/Logistic_Regression_Combined_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import scipy.stats.contingency

# %%
url = 'https://raw.githubusercontent.com/Seitenshi/Board-Exam-Data-Analytics/main/BED%20Test%20-%20Combined.csv'
my_df = pd.read_csv(url)

# %%
my_df
# Out:
#      Subj01  Subj02  Subj03  Gen. Average  Remarks  REGION/PROVINCE/CITY  SEX  \
# 0      74.0    87.0    70.0         76.50      1.0                   0.0  1.0
# 1      60.0    42.0    44.0         49.00      0.0                   0.0  1.0
# 2      66.0    89.0    79.0         77.45      1.0                   0.0  1.0
# 3      77.0    86.0    75.0         79.00      1.0                   1.0  0.0
# 4      74.0    82.0    67.0         73.95      1.0                   0.0  1.0
# ..      ...     ...     ...           ...      ...                   ...  ...
# 291    74.0    72.0    72.0         72.70      1.0                   0.0  1.0
# 292    72.0    28.0    42.0         48.30      0.0                   1.0  1.0
# 293    71.0    74.0    72.0         72.25      1.0                   0.0  0.0
# 294    56.0    74.0    62.0         63.50      0.0                   1.0  0.0
# 295    73.0    62.0    54.0         63.05      0.0                   0.0  1.0
#
#      # OF TAKES CORREL 1  # OF TAKES CORREL 2  # OF TAKES CORREL 3  \
# 0                    1.0                  2.0                  1.0
# 1                    1.0                  1.0                  1.0
# 2                    1.0                  1.0                  2.0
# 3                    1.0                  2.0                  2.0
# 4                    1.0                  1.0                  2.0
# ..                   ...                  ...                  ...
# 291                  1.0                  2.0                  1.0
# 292                  3.0                  2.0                  1.0
# 293                  4.0                  1.0                  3.0
# 294                  1.0                  1.0                  1.0
# 295                  1.0                  1.0                  1.0
#
#      GRADE IN CORREL 1  GRADE IN CORREL 2  GRADE IN CORREL 3
# 0                  1.0                1.0                3.0
# 1                  2.5                1.0                1.0
# 2                  2.5                2.5                1.0
# 3                  1.0                1.0                1.0
# 4                  1.0                1.0                2.0
# ..                 ...                ...                ...
# 291                1.0                1.0                1.5
# 292                1.0                1.0                1.0
# 293                1.5                1.5                1.0
# 294                1.5                2.0                1.0
# 295                1.0                1.0                1.0
#
# [296 rows x 13 columns]

# %%
#change the last column from string to int
my_df['Remarks'] = my_df['Remarks'].replace('FAILED',0)
my_df['Remarks'] = my_df['Remarks'].replace('PASSED',1)

# Drop rows with null values
my_df = my_df.dropna()

my_df
# Out:
#      Subj01  Subj02  Subj03  Gen. Average  Remarks  REGION/PROVINCE/CITY  SEX  \
# 0      74.0    87.0    70.0         76.50      1.0                   0.0  1.0
# 1      60.0    42.0    44.0         49.00      0.0                   0.0  1.0
# 2      66.0    89.0    79.0         77.45      1.0                   0.0  1.0
# 3      77.0    86.0    75.0         79.00      1.0                   1.0  0.0
# 4      74.0    82.0    67.0         73.95      1.0                   0.0  1.0
# ..      ...     ...     ...           ...      ...                   ...  ...
# 291    74.0    72.0    72.0         72.70      1.0                   0.0  1.0
# 292    72.0    28.0    42.0         48.30      0.0                   1.0  1.0
# 293    71.0    74.0    72.0         72.25      1.0                   0.0  0.0
# 294    56.0    74.0    62.0         63.50      0.0                   1.0  0.0
# 295    73.0    62.0    54.0         63.05      0.0                   0.0  1.0
#
#      # OF TAKES CORREL 1  # OF TAKES CORREL 2  # OF TAKES CORREL 3  \
# 0                    1.0                  2.0                  1.0
# 1                    1.0                  1.0                  1.0
# 2                    1.0                  1.0                  2.0
# 3                    1.0                  2.0                  2.0
# 4                    1.0                  1.0                  2.0
# ..                   ...                  ...                  ...
# 291                  1.0                  2.0                  1.0
# 292                  3.0                  2.0                  1.0
# 293                  4.0                  1.0                  3.0
# 294                  1.0                  1.0                  1.0
# 295                  1.0                  1.0                  1.0
#
#      GRADE IN CORREL 1  GRADE IN CORREL 2  GRADE IN CORREL 3
# 0                  1.0                1.0                3.0
# 1                  2.5                1.0                1.0
# 2                  2.5                2.5                1.0
# 3                  1.0                1.0                1.0
# 4                  1.0                1.0                2.0
# ..                 ...                ...                ...
# 291                1.0                1.0                1.5
# 292                1.0                1.0                1.0
# 293                1.5                1.5                1.0
# 294                1.5                2.0                1.0
# 295                1.0                1.0                1.0
#
# [296 rows x 13 columns]

# %%
#Remarks - # of takes correl 1
table = pd.crosstab(my_df["Remarks"],my_df["# OF TAKES CORREL 1"])

#X - # OF TAKES CORREL 1
#y - Remarks

# %%
result_table = scipy.stats.contingency.chi2_contingency(table)

# %%
print('statistics: ', result_table[0])
print('p value: ', result_table[1])
print('degrees of freedom: ', result_table[2])
# Out:
# statistics:  9.588484633316845
# p value:  0.08777124814877428
# degrees of freedom:  5

# %%
#Remarks - # of takes correl 2
table1 = pd.crosstab(my_df["Remarks"],my_df["# OF TAKES CORREL 2"])

#X - # OF TAKES CORREL 2
#y - Remarks

# %%
result_table1 = scipy.stats.contingency.chi2_contingency(table1)

# %%
print('statistics: ', result_table1[0])
print('p value: ', result_table1[1])
print('degrees of freedom: ', result_table1[2])
# Out:
# statistics:  5.336819850324045
# p value:  0.5013943434228894
# degrees of freedom:  6

# %%
#Remarks - # of takes correl 3
table2 = pd.crosstab(my_df["Remarks"],my_df["# OF TAKES CORREL 3"])

#X - # OF TAKES CORREL 3
#y - Remarks

# %%
result_table2 = scipy.stats.contingency.chi2_contingency(table2)

# %%
print('statistics: ', result_table2[0])
print('p value: ', result_table2[1])
print('degrees of freedom: ', result_table2[2])
# Out:
# statistics:  2.2805902263510602
# p value:  0.6843051122377006
# degrees of freedom:  4

# %%
#Remarks - GRADE IN CORREL 1
table3 = pd.crosstab(my_df["Remarks"],my_df["GRADE IN CORREL 1"])

#X - GRADE IN CORREL 1
#y - Remarks

# %%
result_table3 = scipy.stats.contingency.chi2_contingency(table3)

# %%
print('statistics: ', result_table3[0])
print('p value: ', result_table3[1])
print('degrees of freedom: ', result_table3[2])
# Out:
# statistics:  23.481243748173043
# p value:  0.0014048353014949975
# degrees of freedom:  7

# %%
#Remarks - GRADE IN CORREL 2
table4 = pd.crosstab(my_df["Remarks"],my_df["GRADE IN CORREL 2"])

#X - GRADE IN CORREL 2
#y - Remarks

# %%
result_table4 = scipy.stats.contingency.chi2_contingency(table4)

# %%
print('statistics: ', result_table4[0])
print('p value: ', result_table4[1])
print('degrees of freedom: ', result_table4[2])
# Out:
# statistics:  26.949742396182543
# p value:  0.00014798069809540416
# degrees of freedom:  6

# %%
#Remarks - GRADE IN CORREL 3
table5 = pd.crosstab(my_df["Remarks"],my_df["GRADE IN CORREL 3"])

#X - GRADE IN CORREL 3
#y - Remarks

# %%
result_table5 = scipy.stats.contingency.chi2_contingency(table5)

# %%
print('statistics: ', result_table5[0])
print('p value: ', result_table5[1])
print('degrees of freedom: ', result_table5[2])
# Out:
# statistics:  3.608699973436943
# p value:  0.6070075050036605
# degrees of freedom:  5
